# %%
import pandas as pd

# %%
Results = pd.read_csv("../Datasets/Outputs/Stellar_Parameters_JPLUS_SPEEM.csv")

# %%
Results
# Out:
#         TILE_ID  NUMBER          RA        DEC       g  teff_SPEEM  feh_SPEEM  \
# 0         62961     255  152.356656  29.727208  15.188   4486.4385  -0.158543
# 1         62961     268  152.658478  29.730954  16.209   5687.7188  -0.679696
# 2         62961     276  152.944530  29.726223  14.662   5616.8047  -0.017256
# 3         62961     284  152.375819  29.729414  14.511   5985.1400  -0.621603
# 4         62961     315  152.556768  29.729505  13.766   5727.0250  -0.127603
# ...         ...     ...         ...        ...     ...         ...        ...
# 725596    64830   25712  119.965449  39.192885  15.329   6181.9440  -0.072256
# 725597    64830   25721  119.182505  39.188493  16.007   6744.0400  -0.735035
# 725598    64830   25846  120.380894  39.188470  15.930   5457.1950  -0.137869
# 725599    64830   26343  119.589634  39.150565  15.695   6270.5460  -0.708429
# 725600    64830   26400  120.588471  39.153549  14.083   5323.8240  -0.621294
#
#         logg_SPEEM
# ...
